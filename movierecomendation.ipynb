# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
movie=pd.read_csv('movie.csv')
movie.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movie=movie.loc[:,["movieId","title"]]
movie.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)

# %%
rating = pd.read_csv('rating.csv')
rating.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
rating = rating.loc[:,["userId","movieId","rating"]]
rating.head(10)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5
# 5       1      112     3.5
# 6       1      151     4.0
# 7       1      223     4.0
# 8       1      253     4.0
# 9       1      260     4.0

# %%
data = pd.merge(movie,rating)
data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       3     4.0
# 1        1  Toy Story (1995)       6     5.0
# 2        1  Toy Story (1995)       8     4.0
# 3        1  Toy Story (1995)      10     4.0
# 4        1  Toy Story (1995)      11     4.5
# 5        1  Toy Story (1995)      12     4.0
# 6        1  Toy Story (1995)      13     4.0
# 7        1  Toy Story (1995)      14     4.5
# 8        1  Toy Story (1995)      16     3.0
# 9        1  Toy Story (1995)      19     5.0

# %%
data.shape
# Out:
# (11899774, 4)

# %%
data = data.iloc[:1000000,:]

# %%
pivot_table = data.pivot_table(index = ["userId"],columns = ["title"],values = "rating")
pivot_table.head(10)
# Out:
# title   Ace Ventura: When Nature Calls (1995)  Across the Sea of Time (1995)  \
# userId
# 1                                         NaN                            NaN
# 2                                         NaN                            NaN
# 3                                         NaN                            NaN
# 4                                         3.0                            NaN
# 5                                         NaN                            NaN
# 6                                         NaN                            NaN
# 7                                         NaN                            NaN
# 8                                         1.0                            NaN
# 10                                        NaN                            NaN
# 11                                        3.5                            NaN
#
# title   Addiction, The (1995)  Amateur (1994)  \
# userId
# 1                         NaN             NaN
# 2                         NaN             NaN
# 3                         NaN             NaN
# 4                         NaN             NaN
# 5                         NaN             NaN
# 6                         NaN             NaN
# 7                         NaN             NaN
# 8                         NaN             NaN
# 10                        NaN             NaN
# 11                        NaN             NaN
#
# title   Amazing Panda Adventure, The (1995)  American President, The (1995)  \
# userId
# 1                                       NaN                             NaN
# 2                                       NaN                             NaN
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
# 5                                       NaN                             5.0
# 6                                       NaN                             NaN
# 7                                       NaN                             4.0
# 8                                       NaN                             NaN
# 10                                      NaN                             4.0
# 11                                      NaN                             NaN
#
# title   Angela (1995)  Angels and Insects (1995)  \
# userId
# 1                 NaN                        NaN
# 2                 NaN                        NaN
# 3                 NaN                        NaN
# 4                 NaN                        NaN
# 5                 NaN                        NaN
# 6                 NaN                        NaN
# 7                 NaN                        NaN
# 8                 NaN                        NaN
# 10                NaN                        NaN
# 11                NaN                        NaN
#
# title   Anne Frank Remembered (1995)  Antonia's Line (Antonia) (1995)  \
# userId
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# 5                                NaN                              NaN
# 6                                NaN                              NaN
# 7                                NaN                              NaN
# 8                                NaN                              NaN
# 10                               NaN                              NaN
# 11                               NaN                              NaN
#
# title                   ...                    Waiting to Exhale (1995)  \
# userId                  ...
# 1                       ...                                         NaN
# 2                       ...                                         NaN
# 3                       ...                                         NaN
# 4                       ...                                         NaN
# 5                       ...                                         NaN
# 6                       ...                                         NaN
# 7                       ...                                         NaN
# 8                       ...                                         NaN
# 10                      ...                                         NaN
# 11                      ...                                         NaN
#
# title   Walk in the Clouds, A (1995)  Waterworld (1995)  \
# userId
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
# 5                                NaN                NaN
# 6                                NaN                NaN
# 7                                NaN                NaN
# 8                                4.0                3.0
# 10                               NaN                NaN
# 11                               NaN                4.5
#
# title   When Night Is Falling (1995)  \
# userId
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 10                               NaN
# 11                               NaN
#
# title   White Balloon, The (Badkonake sefid) (1995)  \
# userId
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 10                                              NaN
# 11                                              NaN
#
# title   White Man's Burden (1995)  White Squall (1996)  Wild Bill (1995)  \
# userId
# 1                             NaN                  NaN               NaN
# 2                             NaN                  NaN               NaN
# 3                             NaN                  NaN               NaN
# 4                             NaN                  NaN               NaN
# 5                             NaN                  NaN               NaN
# 6                             NaN                  NaN               NaN
# 7                             NaN                  NaN               NaN
# 8                             NaN                  NaN               NaN
# 10                            NaN                  NaN               NaN
# 11                            NaN                  NaN               NaN
#
# title   Wings of Courage (1995)  Young Poisoner's Handbook, The (1995)
# userId
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
# 5                           NaN                                    NaN
# 6                           NaN                                    NaN
# 7                           NaN                                    NaN
# 8                           NaN                                    NaN
# 10                          NaN                                    NaN
# 11                          NaN                                    NaN
#
# [10 rows x 255 columns]

# %%
movie_watched = pivot_table["Wild Bill (1995)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)  
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2392: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# Wild Bill (1995)                              1.000000
# Nobody Loves Me (Keiner liebt mich) (1994)    1.000000
# Sonic Outlaws (1995)                          1.000000
# Lamerica (1994)                               0.934262
# Nico Icon (1995)                              0.795791
# dtype: float64

# %%
movie_watched = pivot_table["Antonia's Line (Antonia) (1995)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)  
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head()
# Out:
# title
# Angela (1995)                                                     1.000000
# Kids of the Round Table (1995)                                    1.000000
# Antonia's Line (Antonia) (1995)                                   1.000000
# Happiness Is in the Field (Bonheur est dans le pré, Le) (1995)    0.910714
# Target (1995)                                                     0.841439
# dtype: float64
