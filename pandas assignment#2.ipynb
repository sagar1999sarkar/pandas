# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('matches.csv')
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Q1 : Find the name of the player who won max number of man of the matches award in the period of 2010 and 2015 while plating in Mumbai [Easy]

# %%
mask1=data['city']=='Mumbai'
mask2=data['season']>2009
mask3=data['season']<2016
#df=data[mask1 & mask2 & mask3]
#df['player_of_match'].value_counts().head(1)
df=data[mask1]
df
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# 36    37    2017  Mumbai  2017-05-01  Royal Challengers Bangalore
# 49    50    2017  Mumbai  2017-05-11              Kings XI Punjab
# 55    56    2017  Mumbai  2017-05-16       Rising Pune Supergiant
# 62    63    2008  Mumbai  2008-04-20               Mumbai Indians
# 71    72    2008  Mumbai  2008-04-27               Mumbai Indians
# 81    82    2008  Mumbai  2008-05-04               Mumbai Indians
# 85    86    2008  Mumbai  2008-05-07             Rajasthan Royals
# 95    96    2008  Mumbai  2008-05-14          Chennai Super Kings
# ...

# %% [markdown]
# # Q2 : Find the team who has won most number of matches with victory margin > 50 [Easy]

# %%
mask4=data['win_by_runs']>50
df2=data[mask4]
df2['winner'].value_counts().head(1)
# Out:
# Chennai Super Kings    11
# Name: winner, dtype: int64

# %% [markdown]
# # # Q3 : Write a function which will take 2 inputs, team 1 and team 2 and their record against each other
#
# # For example if team1->KKR and team2->CSK
#
# # The output should be like KKR 2(matches won by KKR) and CSK 5(matches won by CSK)[Medium]

# %%
print('Enter the first team name')
t1=input()
print('Enter the secon team name')
t2=input()
mask5=data['team1']==t1
mask6=data['team2']==t1
mask7=data['team1']==t2
mask8=data['team2']==t2
win=data[(mask5 + mask6)&(mask7+mask8)]
win['winner'].value_counts()
# Out:
# Enter the first team name
# Kolkata Knight Riders
# Enter the secon team name
# Mumbai Indians
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:180: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))
# Mumbai Indians           16
# Kolkata Knight Riders     5
# Name: winner, dtype: int64

# %% [markdown]
# # Q4 : Plot a bar graph on win_by_wickets col. [Easy]

# %%
#da=pd.data
ax=data.plot.bar(x='winner',y='win_by_wickets',rot=0)

# %% [markdown]
# # Q5 : Write a function which will accept a team name as input and will return it's win percentage after winning the toss[Difficult]

# %%
def winper(t3)
 print('Enter the  team name')
 t3=input()
 mask10=data['team1']==t3
 mask11=data['team2']==t3
 dk=data[mask10 + mask11]
 mask13=dk['toss_winner']==t3
 dk2=dk[mask13]
 dk3=dk2.shape[0]
 mask14=dk2['winner']==t3
 dk4=dk2[mask14]

 dk5=dk4.shape[0]
 kw=((100/dk3)*dk5)
return(kw)
